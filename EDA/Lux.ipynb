# %% [markdown]
# #Lux
# Lux is a Python library that enhances the Pandas data exploration experience by providing an intuitive and interactive interface. It automatically suggests visualizations based on the data and the user's analysis context. Lux enables users to quickly generate visualizations, filter data, and gain insights through its user-friendly interface and recommendations.
#
# Dataset: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data?resource=download

# %%
# !pip install lux

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
import pandas as pd
import lux

# %%
df=pd.read_csv("/content/drive/My Drive/data.csv")

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()
